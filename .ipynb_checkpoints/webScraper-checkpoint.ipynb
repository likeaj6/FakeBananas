# %%
from eventregistry import *
import numpy as np
import pandas as pd

# Print a list of recently added articles mentioning entered words
api_key = 'eda39267-9017-481a-860d-0b565c6d8bf3'
er = EventRegistry(apiKey = api_key)

df = pd.DataFrame()
list_of_articles = []

def get_articles(claim):
    
    #parse claim into a list of keywords
    keywords = claim
    print claim
    
    q = QueryArticlesIter(keywords=QueryItems.AND(keywords))
    
    for article in q.execQuery(er, sortBy = 'date'):
        data = {
            'source': article['source']['title'].encode('utf-8'),
#             'title' : article['title'].encode('utf-8'),
            'url' : article['url'].encode('utf-8'),
            'text' : article['body'].encode('utf-8')
        }
        df = df.append(pd.DataFrame(data=data), ignore_index=True)
       # df.append(data,ignore_index=True)
        print df
        #df.append()
        list_of_articles.append(data)

get_articles(['digging', 'expands', 'decade'])
df
# for query in params:
#     df = get_articles(df, query)
# Out:
# using user provided API key for making requests
# Event Registry host: http://eventregistry.org
# ['digging', 'expands', 'decade']
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-249-633288858eac> in <module>()
#      31         list_of_articles.append(data)
#      32
# ---> 33 get_articles(['digging', 'expands', 'decade'])
#      34 df
#      35 # for query in params:
#
# <ipython-input-249-633288858eac> in get_articles(claim)
#      25             'text' : article['body'].encode('utf-8')
#      26         }
# ---> 27         df = df.append(pd.DataFrame(data=data), ignore_index=True)
#      28        # df.append(data,ignore_index=True)
#      29         print df
#
# UnboundLocalError: local variable 'df' referenced before assignment

# %%
df.to_csv('articles.csv')

# %%
print(list_of_articles[0:5])
len(list_of_articles)
# Out:
# [{'url': 'http://www.businessinsider.com/infrastructure-in-the-us-after-hurricanes-harvey-and-irma-2017-9', 'source': 'Business Insider', 'text': 'The rebuilt levee wall that was destroyed during Hurricane Katrina, in the Lower Ninth Ward of New Orleans, Louisiana. Chris Graythen/Getty Images\n\nThe wonky words infrastructure and resilience have circulated widely of late, particularly since Hurricanes Harvey and Irma struck paralyzing, costly blows in two of America\'s fastest-growing states.\n\nResilience is a property traditionally defined as the ability to bounce back. A host of engineers and urban planners have long warned this trait is sorely lacking in America\'s brittle infrastructure.\n\nMany such experts say the disasters in the sprawling suburban and petro-industrial landscape around Houston and along the crowded coasts of Florida reinforce the urgent idea that resilient infrastructure is needed more than ever, particularly as human-driven climate change helps drive extreme
# ...

# %%
df.shape

# %%
df1 = pd.read_csv('articles.csv')
df1.columns = ['id','source','text',"""'title""" 'url']

bodies = df1.loc[:,['id','text']]
bodies.to_csv('bodies.csv')

# we want claim here, not title
headlines = df1.loc[:,['id','title']]
headlines.to_csv('headlines.csv')

urls = df1.loc[:,['id','source','url']]
urls.to_csv('url.csv')

# %%
bodies
# Out:
#       id                                               text
# 0      0  Sometimes it's time to move on. And while some...
# 1      1  It's not always an easy decision, and in most ...
# 2      2  Olmsted Medical Center is in the midst of a le...
# 3      3  Artificial intelligence - commonly known as A....
# 4      4  Duke University researchers have developed a h...
# 5      5  During the Sunday school class in a Pentecosta...
# 6      6  A polyamory evangelist with a genius IQ said h...
# 7      7  The power holders have almost unrestricted con...
# 8      8  Honolulu: After eight months of living in isol...
# 9      9  Honolulu: After eight months of living in isol...
# 10    10  Honolulu: After eight months of living in isol...
# 11    11  Already a subscriber, but don't have a login?\...
# 12    12  As we age, our tendency is to exist in comfort...
# 13    13  Your cell phone, tablets, laptops and desktop ...
# 14    14  Times film critic Justin Chang is keeping a re...
# ...

# %%
from newspaper import Article

def get_keywords(user_url):
    url = user_url.decode('utf-8')
    article = Article(url)
    article.download()
    article.parse()
    article.nlp()

    keywords = article.keywords
    kl = []
    for word in keywords:
        kl.append(word.encode('utf-8'))
    return kl
url = 'https://www.nytimes.com/2017/09/16/world/asia/kabul-green-zone-afghanistan.html?hp&action=click&pgtype=Homepage&clickSource=story-heading&module=first-column-region&region=top-news&WT.nav=top-news&mtrref=www.nytimes.com&gwh=044CBF2516278CC5DE5B7C307F5B96F1&gwt=pay'
kl = get_keywords(url)
len(kl)
# Out:
# 13

# %%
import random

def get_search_params(keywords):
    search_params = []
    while len(keywords) != 0:
        # Randomly select 3 words
        rm = random.sample(keywords,3)
        # add the list of 3 words to the searchable list
        search_params.append(rm)
        # remove words from the list
        for word in rm:
            keywords.remove(word)

        # put 1 or 2 random words back
        # if 3 words left just append to search_params
        if len(keywords) is 3:
            search_params.append(keywords)
            keywords = []
        # if no words left just exit
        elif len(keywords) is 0:
            keywords = []
        # if 1 word left, append 2 and search_params
        elif len(keywords) is 1:
            keywords.append(random.sample(rm,2)[0:2])
        else:
            keywords.append(random.sample(rm,1)[0])
    return search_params

params = get_search_params(kl)
# Out:
# [['embassy', 'zone', 'decade'],
#  ['american', 'mr', 'kabul'],
#  ['afghan', 'trump', 'digging'],
#  ['decade', 'afghanistan', 'green'],
#  ['decade', 'security', 'mr'],
#  ['digging', 'expands', 'decade']]

# %%
def helper(df,text,numbers):
    df = df.append({'text':text,'numbers':numbers})
    return df
    
df1 = helper(df1,'asdf',123)
df1 = helper(df1,'jkl;',234)
df1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-225-9f413f5414cd> in <module>()
#       4     return df
#       5
# ----> 6 df1 = helper(df1,'asdf',123)
#       7 df1 = helper(df1,'jkl;',234)
#       8 df1
#
# <ipython-input-225-9f413f5414cd> in helper(df, text, numbers)
#       1
#       2 def helper(df,text,numbers):
# ----> 3     df = df.append({'text':text,'numbers':numbers})
#       4     return df
#       5
#
# C:\Users\henry\Anaconda2\lib\site-packages\pandas\core\frame.pyc in append(self, other, ignore_index, verify_integrity)
#    4613                 other = Series(other)
#    4614             if other.name is None and not ignore_index:
# -> 4615                 raise TypeError('Can only append a Series if ignore_index=True'
#    4616                                 ' or if the Series has a name')
#    4617
#
# ...

# %%
params[1] = ['digging', 'expands', 'decade']
params
# Out:
# [['embassy', 'zone', 'decade'], ['digging', 'expands', 'decade']]
