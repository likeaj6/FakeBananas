# %%
from eventregistry import *
import numpy as np
import pandas as pd

# Print a list of recently added articles mentioning entered words
api_key = 'eda39267-9017-481a-860d-0b565c6d8bf3'
er = EventRegistry(apiKey = api_key)

list_of_articles = []
def get_articles(claim):
    
    #parse claim into a list of keywords
    keywords = claim
    print claim
    
    q = QueryArticlesIter(keywords=QueryItems.AND(keywords))
    
    for article in q.execQuery(er, sortBy = 'date'):
        data = {
            'source': article['source']['title'].encode('utf-8'),
            'title' : article['title'].encode('utf-8'),
            'url' : article['url'].encode('utf-8'),
            # 'text' : article['body'].encode('utf-8')
        }
        list_of_articles.append(data)
    
    df = pd.DataFrame()
    for article in list_of_articles:
        df = df.append(article,ignore_index=True)
    df.to_csv('articles.csv')
    
# get_articles(kl)
# Out:
# using user provided API key for making requests
# Event Registry host: http://eventregistry.org

# %%
df1 = pd.read_csv('articles.csv')
df1.columns = ['id','source','text',"""'title""" 'url']

bodies = df1.loc[:,['id','text']]
bodies.to_csv('bodies.csv')

# we want claim here, not title
headlines = df1.loc[:,['id','title']]
headlines.to_csv('headlines.csv')

urls = df1.loc[:,['id','source','url']]
urls.to_csv('url.csv')

# %%
bodies
# Out:
#       id                                               text
# 0      0  Sometimes it's time to move on. And while some...
# 1      1  It's not always an easy decision, and in most ...
# 2      2  Olmsted Medical Center is in the midst of a le...
# 3      3  Artificial intelligence - commonly known as A....
# 4      4  Duke University researchers have developed a h...
# 5      5  During the Sunday school class in a Pentecosta...
# 6      6  A polyamory evangelist with a genius IQ said h...
# 7      7  The power holders have almost unrestricted con...
# 8      8  Honolulu: After eight months of living in isol...
# 9      9  Honolulu: After eight months of living in isol...
# 10    10  Honolulu: After eight months of living in isol...
# 11    11  Already a subscriber, but don't have a login?\...
# 12    12  As we age, our tendency is to exist in comfort...
# 13    13  Your cell phone, tablets, laptops and desktop ...
# 14    14  Times film critic Justin Chang is keeping a re...
# 15    15  Apple's new "spaceship" headquarters peeked ab...
# 16    16  Drug designing tools are software and database...
# 17    17  Cupertino: Apple Inc.'s new "spaceship" headqu...
# 18    18  CUPERTINO, United States: Apple's new "spacesh...
# 19    19  Artificial intelligence has evolved so much th...
# 20    20  Frederick Wiseman's new documentary, "Ex Libri...
# 21    21  Sponsored content is written by Global News' w...
# 22    22  Apple (NasdaqGS: AAPL - news) 's new "spaceshi...
# 23    23  Cloudflare's joint research with "a large e-co...
# 24    24  Patients may one day be diagnosed by computers...
# 25    25  The new cohost of 'SportsCenter' and her partn...
# 26    26  A view of the Steve Jobs Theatre at Apple Park...
# 27    27  Cupertino, United States | AFP | Apple's new "...
# 28    28  The smell of freshly turned soil was heavy in ...
# 29    29  CUPERTINO, United States - Apple's new "spaces...
# ..   ...                                                ...
# 296  296  Part 1: Why Machine Learning Matters. The big ...
# 297  297  Electromagnetic fields (EMFs) are all around u...
# 298  298  By James Eli Shiffer Star Tribune August 19, 2...
# 299  299  CONNECTTWEETLINKEDINCOMMENTEMAILMORE\n\nYou ma...
# 300  300  Mike Sheward was born and raised "in the middl...
# 301  301  There's no denying the growth potential of the...
# 302  302  Summer concert -- Mia & the Riff (Soul, Funk, ...
# 303  303  Awan an indictment: Remember Imran Awan, the I...
# 304  304  While computers are poor at creativity, they a...
# 305  305  (Natural News) Advancements in nanotechnology ...
# 306  306  Consulting engineer and RW family member confr...
# 307  307  Judith Giuliani and Rudy Giuliani attend Ovari...
# 308  308  People suffering from chronic pain can now get...
# 309  309  Tech billionaires Elon Musk and Mark Zuckerber...
# 310  310  India's achievements in space, marked by missi...
# 311  311  e-Therapeutics has created a unique computer-b...
# 312  312  FELTON, California, August 17, 2017 /PRNewswir...
# 313  313  FELTON, California, August 17, 2017 /PRNewswir...
# 314  314  FELTON, California, August 17, 2017 /PRNewswir...
# 315  315  Allied Minds plc is referred to as "Allied Min...
# 316  316  Police Harass Auchi Polytechnic Student For Dr...
# 317  317  Sponsored content is written by Global News' w...
# 318  318  Do you wear runners, drink coffee or own a mob...
# 319  319  (Cycle Computing cofounder and CEO Jason Stowe...
# 320  320  Judith Cameron's 91-year-old dad is in decline...
# 321  321  In the early 1970s, the Salkinds -- son Ilya a...
# 322  322  Cycle was an early partner with AWS and Google...
# 323  323  Sophisticated software could help doctors make...
# 324  324  The ambitions of Barcelona's Supercomputing Ce...
# 325  325  ANN ARBOR, MI - People who've been holding out...
#
# [326 rows x 2 columns]

# %%
from newspaper import Article

url = u'https://www.nytimes.com/2017/09/15/opinion/sports-gender-gap-serena.html?action=click&pgtype=Homepage&clickSource=story-heading&module=opinion-c-col-right-region&region=opinion-c-col-right-region&WT.nav=opinion-c-col-right-region'
article = Article(url)
article.download()
article.parse()
article.nlp()

keywords = article.keywords
kl = []
for word in keywords:
    kl.append(word.encode('utf-8'))
print kl
# Out:
# ['ratings', 'child', 'short', 'womens', 'gender', 'men', 'told', 'gap', 'fans', 'female', 'fall', 'venus', 'male', 'athletes', 'tennis']

# %%
article.summary
# Out:
# u'Minimum wage and former felon employmentWorkers in 13 states and four cities will see increases to the minimum wage.\nNew Jersey residents voted to raise the state\u2019s minimum wage by $1 to $8.25 per hour.\nArkansas: The state becomes the latest state requiring voters show a picture ID at the voting booth.\nCalifornia is also raising its minimum wage to $9 per hour, but workers must wait until July to see the addition.\nOregon: Family leave in Oregon has been expanded to allow eligible employees two weeks of paid leave to handle the death of a family member.'

# %%
from newsplease import NewsPlase
article = NewsPlease.from_url('https://www.nytimes.com/2017/09/15/opinion/sports-gender-gap-serena.html?action=click&pgtype=Homepage&clickSource=story-heading&module=opinion-c-col-right-region&region=opinion-c-col-right-region&WT.nav=opinion-c-col-right-region')
print article.title
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-735f41499d87> in <module>()
# ----> 1 from newsplease import NewsPlase
#       2 article = NewsPlease.from_url('https://www.nytimes.com/2017/09/15/opinion/sports-gender-gap-serena.html?action=click&pgtype=Homepage&clickSource=story-heading&module=opinion-c-col-right-region&region=opinion-c-col-right-region&WT.nav=opinion-c-col-right-region')
#       3 print article.title
#
# ImportError: cannot import name NewsPlase
